# %% [markdown]
# # ▶️ Usage Examples
#
# ## 1. Ziel dieses Dokuments
# Dieses Notebook zeigt konkrete Beispiele, wie das Projekt genutzt wird –
# sowohl über Python-Code als auch über die Kommandozeile (CLI).
#
# ---
#
# ## 2. Nutzung im Python-Code (Library Usage)
#
# ### 📌 Einfaches Beispiel
# ```python

# %%
```python
from pydata_processor.processor import DataProcessor

dp = DataProcessor()
result = dp.run("data.csv")
print(result)
```

# %% [markdown]
# Erwartetes Verhalten
#
# Datei wird eingelesen
#
# Daten werden verarbeitet (Transform/Filter/Validierung)
#
# Ergebnis wird zurückgegeben oder gespeichert
#
#
# 3. Nutzung über die Kommandozeile (CLI Usage)

# %% [markdown]
# 📌 Hilfe anzeigen

# %% [markdown]
# python -m pydata_processor --help

# %% [markdown]
# 📌 Datei verarbeiten

# %% [markdown]
# python -m pydata_processor process input.csv --out output.csv

# %% [markdown]
# input.csv → Eingabedatei
#
# output.csv → Ausgabedatei
#
# Weitere Flags können je nach Projekt hinzugefügt werden
#
# 4. Beispiel: Erwarteter Output
# Loaded input.csv
# Processed 100 rows
# Saved to output.csv
#
# 5. Nächste Schritte
#
# Erweiterte Beispiele hinzufügen
#
# Fehlerszenarien testen
#
# Parameter erweitern
#
# Integration mit Tests (siehe 04_testing.ipynb)
