# %% [markdown]
# # ⚙️ Setup & Installation Guide
#
# ## 1. Ziel dieses Dokuments
# Dieses Notebook erklärt, wie man das Projekt installiert und ausführt.
# Es richtet sich an alle, die das Projekt lokal verwenden oder erweitern möchten.
#
# ---
#
# ## 2. Voraussetzungen
# - Python 3.10+
# - Pip (Python Package Manager)
# - Virtuelle Umgebung (optional, aber empfohlen)
# - Git (zum Klonen des Repositories)
#
# ---
#
# ## 3. Installation
#
# ### 📌 Repository klonen

# %% [markdown]
# ```bash
# git clone https://github.com/USERNAME/python-data-processor.git
# cd python-data-processor

# %% [markdown]
# 📌 Virtuelle Umgebung erstellen (optional, empfohlen)
#
# python -m venv venv
# source venv/bin/activate     # macOS / Linux
# venv\Scripts\activate        # Windows
#
# 📌 Abhängigkeiten installieren
#
# pip install -r requirements.txt
#
# 4. Projektstruktur verstehen
#
# Eine Übersicht über das Projekt findest du in:
#
# ➡️ 01_overview.ipynb
#
# Dort wird erklärt:
#
# Modulaufbau
# Architektur
# Hauptfunktionen
#
# 5. Nächste Schritte
#
# Nachdem die Installation abgeschlossen ist, kannst du:
#
# ✔ Das Projekt ausführen
#
# ➡️ Siehe: 03_usage.ipynb
#
# ✔ Tests laufen lassen
#
# ➡️ Siehe: 04_testing.ipynb
#
# ✔ Dokumentation lesen
