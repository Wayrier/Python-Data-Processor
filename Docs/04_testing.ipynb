# %% [markdown]
# ---
#
# # 📒 **04_testing.ipynb**
#
# ```markdown
# # 🧪 Testing & Quality Assurance
#
# ## 1. Ziel dieses Dokuments
# Fokus auf Unit Tests, Integration Tests und Teststrategie.
#
# ---
# ## 2. Setup für Tests
#
# ### Tests ausführen:

# %% [markdown]
# ```bash
# pytest -v

# %% [markdown]
# Tests finden sich unter:
# /tests
#
# 3. Beispieltest

# %% [markdown]
# def test_processor_runs():
#     dp = DataProcessor()
#     assert dp.run("test.csv") is not None

# %% [markdown]
# 4. Testabdeckung messen

# %% [markdown]
# pytest --cov=pydata_processor

# %% [markdown]
# 5. Nächste Schritte
#
# Edge Cases testen
#
# CLI Tests erweitern
